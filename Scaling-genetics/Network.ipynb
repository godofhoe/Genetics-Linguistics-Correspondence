# %%
import networkx as nx
import time
import random 
import bisect 
import math 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Module.network import *
from Module.count import *
from Module.Curve_Fitting_MLE import *
from scipy.optimize import curve_fit
plt.style.use('classic')
# %matplotlib inline

# %%
#encode = "UTF-16" #(1)
encode = "UTF-8"   #(2)
##if anything gets into trouble, use (1) instead of (2), and vise versa.
name = 'ON24lambda05'
filename = name + '.txt' #change filename if you want to get statictical information of another

# %%
##text file.
big, syl, word, longest = info(filename, encode)
# Out:
# read file successfully!
# Successfully count protein freqency!(ON24lambda05.txt)
# Successfully count dom freqency!
# Successfully build data frames!

# %%
V, H = geometric_sequence(word, syl)
need_line = 'Y'
number_of_lines = 4
Color = '#ff0000'
FORMAT = 'png' #the format of your picture

tStart = time.time()
coordinate = draw_RRD_plot(big, word, syl, longest, name, V, H,
                           need_line, number_of_lines, Color, FORMAT)
tEnd = time.time()
print(tEnd-tStart)
# Out:
# 1.2696399688720703

# %%
graph_word, graph_syl = build_edge(coordinate)
G_word, cluster_word, word_degree_sequence = graph_word[0], graph_word[1], graph_word[2]
G_syl, cluster_syl, syl_degree_sequence = graph_syl[0], graph_syl[1], graph_syl[2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2b16579bfd2a> in <module>
# ----> 1 graph_word, graph_syl = build_edge(coordinate)
#       2 G_word, cluster_word, word_degree_sequence = graph_word[0], graph_word[1], graph_word[2]
#       3 G_syl, cluster_syl, syl_degree_sequence = graph_syl[0], graph_syl[1], graph_syl[2]
#
# ~/Downloads/Scaling-DNA/Module/network.py in build_edge(coordinate)
#      53     for j in range(max(y)):
#      54         col = []
# ---> 55         for i in temp:
#      56             if i[1] == j+1:   #word share the same syl
#      57                 col.append(i[0])
#
# KeyboardInterrupt:

# %%
plot_cluster_word(name, cluster_word, FORMAT = 'pdf', Path = '')
plot_degree_word(name, word_degree_sequence, FORMAT = 'pdf', Path = '')

# %%
sum_shortest_path_word = build_shortest_path(G_word)

# %%
plot_shortest_path(name, sum_shortest_path_word, G_name = '$G_b$')

# %%
plot_cluster_syl(name, cluster_syl, FORMAT = 'pdf', Path = '')
plot_degree_syl(name, syl_degree_sequence, FORMAT = 'pdf', Path = '')

# %%
sum_shortest_path_syl = build_shortest_path(G_syl)

# %%
plot_shortest_path(name, sum_shoretst_path_syl, G_name = '$G_c$')
